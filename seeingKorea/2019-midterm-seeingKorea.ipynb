# %% [markdown]
# ## Your Name:
# ## Your Id:

# %%
# %matplotlib inline

# %% [markdown]
# # Seeing Korea, MidTerm Exam, 2019
#
# - Import any python module if necessary
# - Use `skimage` to do grayscale conversion
# - 10 points each.
# - This is an open-book open-internet exam. The rule is in general the same as a traditional one (Don't do any cheating).
#     - You may use any information you can find through a search engine like Google, Yahoo, etc
#     - You may use any book, notes, or document.
#     - You must not ask any person nor talk to any people online/offline.
#     - You must not get any help from your friend or any people.
#     - You must not send any text or image in this examination to any one during the examination.

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Color pixel counting
# 1. Count the number of red channel pixels whose values are greater than or equal to 128.
# 2. What is the percentage of the red dominant pixels?
#     - A pixel is red-dominant if its red color intensity is greater than the other color intensities.
#
# #### Use the image provided below.

# %%
image_url1 = 'https://upload.wikimedia.org/wikipedia/en/thumb/e/ec/7th_century_painting_of_Koreans.png/1920px-7th_century_painting_of_Koreans.png'
im1 = imageio.imread (image_url1)
print(im1.shape)
fig, ax = plt.subplots (figsize=(10,10))
ax.imshow (im1)
# Out:
# (1273, 1920, 4)

# %% [markdown]
# ### Provide your answer in the cell below.
# You may use more cells if necessary.

# %% [markdown]
# ## 2. How many edge pixels?
# 1. convert the image to grayscale
# 2. apply Sobel (edge magnitude) operator
# 3. find threshold as the mean of all the edge intensities
# 4. apply binarization
# 5. count the number of edge pixels frm the binary image.
# 6. find another threshold of your own that makes the binary image yield a better visual perception.
# 7. Display the binary image.

# %%
image_url2 = 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Anapji_Pond-Gyeongju-Korea-2006-09.jpg/1920px-Anapji_Pond-Gyeongju-Korea-2006-09.jpg'
im2 = imageio.imread (image_url2)
fig, ax = plt.subplots (figsize=(10,10))
ax.imshow (im2)

# %% [markdown]
# ## 3. Morphological Filtering
#
#     - use the image above in Problem 2
#
# 0. convert to a grayscale image (use `skimage`)
# 1. apply `Canny` edge operator to get a binary edge map
# 2. apply `dilation` with structure element `diamond(3)`
# 3. do some pixel operation so that the output image has color values of the original image only at the pixels where the dilated edge map is non-zero; that is, any pixel where the dilated edge map is zero must have black color, the other pixels retain the original RGB color
# 4. display the output image

# %% [markdown]
# ## 4. Morphological Filtering to a Color image
# 0. Apply `Opening` operation to each of the RGB channels
#     - use `disk(5)` for filtering
# 1. display the output image

# %%
image_url3 = 'https://upload.wikimedia.org/wikipedia/en/8/84/Yayeon_%28Night_Banquet%29.jpg'
im3 = imageio.imread (image_url3)
fig, ax = plt.subplots (figsize=(10,10))
ax.imshow (im3)

# %% [markdown]
# ## 5. Morphological Fitering
# 0. make a structuring element by yourself:
#     - size = 11 x 11
#     - shape: cross
# 1. apply `Closing`, `Opening`, `Erosion` and  `Dilation`
# 2. display the results.

# %%
image_url5 = 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/ce/%D0%9F%D0%B0%D1%80%D0%B0%D0%BD%D0%B0%D0%BB%D1%8C%D1%81%D0%BA%D0%B8%D0%B5_%D0%BD%D0%BE%D1%87%D0%B8.jpg/1920px-%D0%9F%D0%B0%D1%80%D0%B0%D0%BD%D0%B0%D0%BB%D1%8C%D1%81%D0%BA%D0%B8%D0%B5_%D0%BD%D0%BE%D1%87%D0%B8.jpg'
im5 = imageio.imread (image_url5)
fig, ax = plt.subplots (figsize=(10,10))
ax.imshow (im5)

# %% [markdown]
# ## 6. Binarization
# 1. Obtain a grayscale image and display the histogram of its intensity values
# 1. display/plot the histogram of the grayscale image.
# 1. find an appropriate threshold value
# 1. apply binarization
# 1. apply a morphological operation so that the blobs of characters in the binary image may become larger or expanded.
# 1. count the number of non-zero pixels in the binary image obtained from the morphologal operation above
# 1. display the binary image

# %%
image_url6 = 'http://ojsfile.ohmynews.com/STD_IMG_FILE/2013/1019/IE001634376_STD.jpg'
im6 = imageio.imread (image_url6)
print(im6.shape)
fig, ax = plt.subplots (figsize=(10,10))
ax.imshow (im6)
# Out:
# (539, 382, 3)

# %% [markdown]
# ## EOF

# %% [markdown]
# ### Submit this file to
# - `yndk@sogang.ac.kr`
# - with subject: mid-term <yourname>

# %% [markdown]
# ### Extra 5 points
#
# Provide an example where image processing or computer vision is utilized in the area of Korean Studies.
